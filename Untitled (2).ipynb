# %%
txt = input("Введите что-нибудь:")
l1 = len(txt)
a_list = []
a_list += txt
a_list.insert(0,a_list[l1-1])
a_list.pop(l1)
a_list.insert(l1+1,a_list[1])
a_list.pop(1)
print (a_list)
# Out:
# Введите что-нибудь: ghf
# ['f', 'h', 'g']

# %%
def fact (x) :
    if x==1:
        return 1
    return fact(x-1)*x
print (fact(9))
# Out:
# 362880

# %%
import random
ver = 0
while (ver == 0):
    player =int(input("1 - rock, 2 - scissors, 3 - paper. "))
    if (player == 1 or player == 2 or player == 3):
        ver = 1
if player == 1:
       print("you choose rock.")
if player == 2:
       print("you choose scissors.")
if player == 3:
       print("you choose paper.")
comp = random.randint(1, 3)
if comp == 1:
       print("computer choose rock.")
if comp == 2:
       print("computer choose scissors.")
if comp == 3:
       print("computer choose paper.")
# choosing the winner    
if player == comp:
       win = 0
if player == 1 and comp == 2:
       win = 1
if player == 1 and comp == 3:
       win = 2
if player  == 2 and comp == 1:
       win = 2
if player == 2 and comp == 3:                                      
       win = 1
if player == 3 and comp == 1:
       win = 1                                    
if player == 3 and comp == 2:
       win = 2
if win == 0:
       print("draw!")
if win == 1 :
       print("the player win!")
if win == 2:
       print ("the computer win!")
# Out:
# 1 - rock, 2 - scissors, 3 - paper.  1
# you choose rock.
# computer choose rock.
# draw!
